# %% [markdown]
# # Work Out - Introducción a Python

# %% [markdown]
# ## Crear un programa que calcule la cuota de una hipoteca
#
# Las cuotas hipotecarias se calculan utilizando la fórmula del interés frances. El objetivo del ejercicio es crear un programa que solicite al usuario los datos de su hipoteca (cantidad, intereses, y plazo en años) y le devuelva la cuota mensual a pagar
#
# La formula del interés frances es la siguiente:
# \begin{align*}
# C=V \frac{(1+i)^n i}{(1+i)^n -i}
# \end{align*}
#
#
#     C = Cuota a pagar
#     V = Cantidad del préstamo hipotecario
#     i = tipo de interés del período
#     n = número de cuotas

# %%
# Declares and asks for user to input loan amount. Then converts to float

loanAmount = input('Enter loan amount \n')
loanAmount = float(loanAmount)

# Declares and asks user to input number of payments in years. Then converts to float. Years * 12 to get
#  total number of months
meses = float(input('How many years will you have the loan? \n')) *12
# cuotas = int ( years) * 12
# meses = float(years) * 12

# Declares and asks user to input interest rate. Then converts to float and input interest rate is /100/12
interestRate = input('Enter Interest Rate \n')
interestRate = int(interestRate) / 100 / 12

# Formula to calculate monthly payments
mortgagePayment = loanAmount * (interestRate * (1 + interestRate)
                                ** meses) / ((1 + interestRate) ** meses - 1)

# Prints monthly payment on next line and reformat the string to a float using 2 decimal places
print("The monthly mortgage payment is\n (%.2f) " % mortgagePayment)
# Out:
# Enter loan amount
#  120000
# How many years will you have the loan?
#  12
# Enter Interest Rate
#  2
# The monthly mortgage payment is
#  (938.02)

# %% [markdown]
# # Crear un programa que calcule el plan de amortización
#
# El objetivo del ejercicio es crear un programa que solicite al usuario los datos de su hipoteca (cantidad, intereses, y plazo en años) y le devuelva el plan de amortización.
#
# En cada cuota se pagan intereses por el capital restante, y se devuelve capital hasta la cuota mensual. El capital restante ha de ser actualizado restandole el capital devuelto.

# %%
number = 1
balance = loanAmount

print ("mes  cuota  intereses  principal  pendiente")

for number in range(int(meses)):
    interest = balance * interestRate
    principal = mortgagePayment - interest
    balance = balance - principal
    print (number," %.2f "  % mortgagePayment, " %.2f "  %  interest, " %.2f "  % principal, " %.2f "  % balance)
# Out:
# mes  cuota  intereses  principal  pendiente
# 0  758.89   450.00   308.89   179691.11
# 1  758.89   449.23   309.66   179381.45
# 2  758.89   448.45   310.43   179071.02
# 3  758.89   447.68   311.21   178759.81
# 4  758.89   446.90   311.99   178447.82
# 5  758.89   446.12   312.77   178135.05
# 6  758.89   445.34   313.55   177821.50
# 7  758.89   444.55   314.33   177507.17
# 8  758.89   443.77   315.12   177192.05
# 9  758.89   442.98   315.91   176876.14
# 10  758.89   442.19   316.70   176559.45
# 11  758.89   441.40   317.49   176241.96
# 12  758.89   440.60   318.28   175923.68
# 13  758.89   439.81   319.08   175604.60
# 14  758.89   439.01   319.88   175284.72
# 15  758.89   438.21   320.68   174964.05
# 16  758.89   437.41   321.48   174642.57
# 17  758.89   436.61   322.28   174320.29
# 18  758.89   435.80   323.09   173997.20
# 19  758.89   434.99   323.89   173673.31
# 20  758.89   434.18   324.70   173348.60
# 21  758.89   433.37   325.52   173023.09
# 22  758.89   432.56   326.33   172696.76
# 23  758.89   431.74   327.15   172369.61
# 321  758.89   70.42   688.47   27477.56
# 322  758.89   68.69   690.19   26787.37
# 323  758.89   66.97   691.92   26095.45
# 324  758.89   65.24   693.65   25401.80
# 325  758.89   63.50   695.38   24706.42
# 326  758.89   61.77   697.12   24009.30
# 327  758.89   60.02   698.86   23310.43
# 328  758.89   58.28   700.61   22609.82
# 329  758.89   56.52   702.36   21907.46
# 330  758.89   54.77   704.12   21203.34
# 331  758.89   53.01   705.88   20497.46
# 332  758.89   51.24   707.64   19789.82
# 333  758.89   49.47   709.41   19080.41
# 334  758.89   47.70   711.19   18369.22
# 335  758.89   45.92   712.96   17656.26
# 336  758.89   44.14   714.75   16941.51
# 337  758.89   42.35   716.53   16224.98
# 338  758.89   40.56   718.32   15506.65
# 339  758.89   38.77   720.12   14786.53
# 340  758.89   36.97   721.92   14064.61
# 341  758.89   35.16   723.73   13340.88
# 342  758.89   33.35   725.54   12615.35
# 343  758.89   31.54   727.35   11888.00
# 344  758.89   29.72   729.17   11158.83
# 345  758.89   27.90   730.99   10427.84
# 346  758.89   26.07   732.82   9695.02
# 347  758.89   24.24   734.65   8960.37
# 348  758.89   22.40   736.49   8223.89
# 349  758.89   20.56   738.33   7485.56
# 350  758.89   18.71   740.17   6745.39
# 351  758.89   16.86   742.02   6003.36
# 352  758.89   15.01   743.88   5259.48
# 353  758.89   13.15   745.74   4513.75
# 354  758.89   11.28   747.60   3766.14
# 355  758.89   9.42   749.47   3016.67
# 356  758.89   7.54   751.35   2265.33
# 357  758.89   5.66   753.22   1512.10
# 358  758.89   3.78   755.11   756.99
# 359  758.89   1.89   756.99   -0.00

# %% [markdown]
# # Crear un programa que resuelva una ecuacción de segundo grado
#
# El objetivo del programa es resolver la ecuacción de sgundo grado
#
# \begin{align*}
# ax^2+bx+c = 0
# \end{align*}
#
# Pasando como parámetros los coeficientes de la ecuacción. La resolución de la ecuacción es la siguiente:
#
# \begin{align*}
# x=\frac{-b \pm \sqrt{b^2-4ac}}{2a}
# \end{align*}

# %%
import math  # Makes the math library available.

print("This program finds the real solutions to a quadratic")
print()

a = float(input("Enter coefficient a: "))
b = float(input("Enter coefficient b: "))
c = float(input("Enter coefficient c: "))

discRoot = math.sqrt(b * b - 4 * a * c)
root1 = (-b + discRoot) / (2 * a)
root2 = (-b - discRoot) / (2 * a)

print()
print("The solutions are:", root1, root2 )

# %% [markdown]
# ## Crear un programa que calcule el factorial

# %%
num = int(input("introduce un numero entero distinto de cero: "))
factorial = 1

for i in range(1,num + 1):
    factorial = factorial*i
    
print("The factorial of", num, "is", factorial)
# Out:
# introduce un numero entero distinto de cero:  3
# The factorial of 3 is 6

# %% [markdown]
# ## Crear un programa que calcule el average
#
# El programa pedirá que se diga cuantos números se quieren introducir, y enseñara un prompt para incluirlos, y calculará el average.

# %%
n = int(input("How many numbers do you have? "))
total = 0.0
for i in range(n):
    x = float(input("Enter a number >> "))
    total = total + x
print("\nThe average of the numbers is", total / n)
# Out:
# How many numbers do you have?  4
# Enter a number >>  5
# Enter a number >>  6
# Enter a number >>  7
# Enter a number >>  8
# The average of the numbers is 6.5
